# %%
import h5py
import glob
import os
import sys
import sympy
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc, accuracy_score
from sklearn.preprocessing import StandardScaler
import tensorflow.keras.backend as K
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import roc_curve, auc, accuracy_score, r2_score
from tensorflow.keras.regularizers import Regularizer
from tensorflow.keras.initializers import Zeros, RandomNormal
from tensorflow.keras.layers import *
from tensorflow import keras
from tensorflow.keras import layers, models, Model
from sklearn.metrics import roc_curve, auc
import tensorflow.keras.backend as K
import qkeras
from qkeras import *

np.random.seed(42)
tf.random.set_seed(42)

X_train = np.load('X_train.npy', mmap_mode='r')
X_val = np.load('X_val.npy', mmap_mode='r')
X_test = np.load('X_test.npy', mmap_mode='r')
Y_train = np.load('Y_train.npy', mmap_mode='r')
Y_val = np.load('Y_val.npy', mmap_mode='r')
Y_test = np.load('Y_test.npy', mmap_mode='r')
pt_truth_test = np.load('pt_truth_test.npy', mmap_mode='r')

# model 1 (y-local, y-size)
X_train = X_train[:,:2]
X_val = X_val[:,:2]
X_test = X_test[:,:2]

# model 2 (y-local, [13 y rows of cluster charge])
#X_train = np.delete(X_train, [1], axis=1)
#X_val = np.delete(X_val, [1], axis=1)
#X_test = np.delete(X_test, [1], axis=1)

X_test = X_test[:500000]
Y_test = Y_test[:500000]
pt_truth_test = pt_truth_test[:500000]

print('X_train shape: ' + str(X_train.shape))
print('X_val   shape: ' + str(X_val.shape))
print('X_test  shape: ' + str(X_test.shape))
print('Y_train shape: ' + str(Y_train.shape))
print('Y_val   shape: ' + str(Y_val.shape))
print('Y_test  shape: ' + str(Y_test.shape))
print('pt_truth_test  shape: ' + str(pt_truth_test.shape))

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)
# Out:
# X_train shape: (226993, 2)
# X_val   shape: (18917, 2)
# X_test  shape: (500000, 2)
# Y_train shape: (226993, 3)
# Y_val   shape: (18917, 3)
# Y_test  shape: (500000, 3)
# pt_truth_test  shape: (500000,)

# %% [markdown]
# ## nn model

# %%
quantizer = quantized_bits(16, 6, alpha=1)
quantized_relu = 'quantized_relu(16, 6)'

x_input = keras.Input(shape=(X_train.shape[1],), name='input')

x = QDense(128, use_bias=True, name='dense1', kernel_quantizer=quantizer, bias_quantizer=quantizer)(x_input)
x = QActivation(quantized_relu, name='relu1')(x)
    
x = QDense(3, use_bias=True, name='dense2', kernel_quantizer=quantizer, bias_quantizer=quantizer)(x)
x = layers.Softmax(name='softmax')(x)
#x = layers.Activation('sigmoid')(x)

model = keras.Model(x_input, x, name='model')

model.compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=0.001),
              loss='categorical_crossentropy', metrics = ['accuracy'])
#model.compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=0.001),
#              loss='binary_crossentropy', metrics = ['accuracy'])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 2)]               0
#
#  dense1 (QDense)             (None, 128)               384
#
#  relu1 (QActivation)         (None, 128)               0
#
#  dense2 (QDense)             (None, 3)                 387
#
#  softmax (Softmax)           (None, 3)                 0
#
# =================================================================
# Total params: 771 (3.01 KB)
# Trainable params: 771 (3.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, Y_train,
                    validation_data = (X_val, Y_val),
                    epochs=120, batch_size=128)

plt.figure(figsize = (15,10))
axes = plt.subplot(2, 2, 1)
axes.plot(history.history['loss'], label = 'train loss')
axes.plot(history.history['val_loss'], label = 'val loss')
axes.legend(loc = "upper right")
axes.set_xlabel('Epoch')
axes.set_ylabel('Loss')


Y_nn_pred = model.predict(X_test)
print("Accuracy: {}".format(accuracy_score(np.argmax(Y_test, axis=1), np.argmax(Y_nn_pred, axis=1))))


def plot_roc(y_test, y_pred, labels):
    for x, label in enumerate(labels):        
        fpr, tpr, _ = roc_curve(y_test[:, x], y_pred[:, x])
        plt.plot(fpr, tpr, label='{0}, {1:.1f}'.format(label, auc(fpr, tpr)*100.), linestyle='-')
    #plt.semilogy()
    #plt.semilogx()
    plt.ylabel("Signal Efficiency")
    plt.xlabel("Background Efficiency")
    #plt.ylim(0.00001, 1)
    #plt.xlim(0.00001, 1)
    plt.grid(True)
    plt.legend(loc='best', fontsize=10)  
    
plt.figure(figsize=(4, 4))
plot_roc(Y_test, Y_nn_pred, ['Low pT (pos)','Low pT (neg)','High pT'])
#plot_roc(Y_test, Y_nn_pred, [' '])
# Out:
# Epoch 1/120
# 1774/1774 [==============================] - 1s 646us/step - loss: 0.7500 - accuracy: 0.6534 - val_loss: 0.7261 - val_accuracy: 0.6559
# Epoch 2/120
# 1774/1774 [==============================] - 1s 589us/step - loss: 0.7245 - accuracy: 0.6589 - val_loss: 0.7201 - val_accuracy: 0.6607
# Epoch 3/120
# 1774/1774 [==============================] - 1s 604us/step - loss: 0.7232 - accuracy: 0.6592 - val_loss: 0.7242 - val_accuracy: 0.6591
# Epoch 4/120
# 1774/1774 [==============================] - 1s 594us/step - loss: 0.7224 - accuracy: 0.6587 - val_loss: 0.7194 - val_accuracy: 0.6584
# Epoch 5/120
# 1774/1774 [==============================] - 1s 584us/step - loss: 0.7216 - accuracy: 0.6596 - val_loss: 0.7178 - val_accuracy: 0.6603
# Epoch 6/120
# 1774/1774 [==============================] - 1s 606us/step - loss: 0.7212 - accuracy: 0.6596 - val_loss: 0.7168 - val_accuracy: 0.6615
# Epoch 7/120
# 1774/1774 [==============================] - 1s 545us/step - loss: 0.7210 - accuracy: 0.6596 - val_loss: 0.7177 - val_accuracy: 0.6594
# Epoch 8/120
# 1774/1774 [==============================] - 1s 541us/step - loss: 0.7205 - accuracy: 0.6595 - val_loss: 0.7189 - val_accuracy: 0.6588
# Epoch 9/120
# 1774/1774 [==============================] - 1s 541us/step - loss: 0.7203 - accuracy: 0.6592 - val_loss: 0.7162 - val_accuracy: 0.6610
# Epoch 10/120
# 1774/1774 [==============================] - 1s 542us/step - loss: 0.7203 - accuracy: 0.6593 - val_loss: 0.7186 - val_accuracy: 0.6589
# Epoch 11/120
# 1774/1774 [==============================] - 1s 540us/step - loss: 0.7198 - accuracy: 0.6594 - val_loss: 0.7144 - val_accuracy: 0.6616
# Epoch 12/120
# 1774/1774 [==============================] - 1s 542us/step - loss: 0.7194 - accuracy: 0.6594 - val_loss: 0.7149 - val_accuracy: 0.6613
# Epoch 13/120
# 1774/1774 [==============================] - 1s 534us/step - loss: 0.7189 - accuracy: 0.6594 - val_loss: 0.7141 - val_accuracy: 0.6601
# Epoch 14/120
# 1774/1774 [==============================] - 1s 532us/step - loss: 0.7185 - accuracy: 0.6600 - val_loss: 0.7157 - val_accuracy: 0.6612
# Epoch 15/120
# 1774/1774 [==============================] - 1s 530us/step - loss: 0.7180 - accuracy: 0.6603 - val_loss: 0.7142 - val_accuracy: 0.6616
# Epoch 16/120
# Epoch 115/120
# 1774/1774 [==============================] - 1s 632us/step - loss: 0.7157 - accuracy: 0.6610 - val_loss: 0.7119 - val_accuracy: 0.6624
# Epoch 116/120
# 1774/1774 [==============================] - 1s 625us/step - loss: 0.7157 - accuracy: 0.6613 - val_loss: 0.7140 - val_accuracy: 0.6607
# Epoch 117/120
# 1774/1774 [==============================] - 1s 614us/step - loss: 0.7157 - accuracy: 0.6610 - val_loss: 0.7126 - val_accuracy: 0.6601
# Epoch 118/120
# 1774/1774 [==============================] - 1s 608us/step - loss: 0.7155 - accuracy: 0.6614 - val_loss: 0.7126 - val_accuracy: 0.6616
# Epoch 119/120
# 1774/1774 [==============================] - 1s 589us/step - loss: 0.7156 - accuracy: 0.6607 - val_loss: 0.7119 - val_accuracy: 0.6612
# Epoch 120/120
# 1774/1774 [==============================] - 1s 546us/step - loss: 0.7156 - accuracy: 0.6609 - val_loss: 0.7118 - val_accuracy: 0.6621
# 15625/15625 [==============================] - 4s 251us/step
# Accuracy: 0.496434

# %%
plt.figure(figsize=(4, 4))
custom_bins = np.arange(-4.5, 4.5, 0.04)
bin_centers = 0.5 * (custom_bins[:-1] + custom_bins[1:])

indices_001_nn = np.argmax(Y_nn_pred, axis=1) == 2

total_counts_nn, _ = np.histogram(pt_truth_test, bins=custom_bins)
class_001_counts_nn, _ = np.histogram(pt_truth_test[indices_001_nn], bins=custom_bins)

proportions_nn = class_001_counts_nn / total_counts_nn
proportions_nn = np.nan_to_num(proportions_nn)

plt.scatter(bin_centers, proportions_nn, marker='.', label='nn', alpha=0.5, color='blue')
plt.axvline(x=0.2, color='grey', linestyle='--', alpha=0.5)
plt.axvline(x=-0.2, color='grey', linestyle='--', alpha=0.5)

plt.legend(fontsize=10)
plt.xlabel('True pT [GeV]')
plt.ylabel('Fraction')
plt.title('Fraction of clusters selected as having |pT| > 0.2 GeV')
plt.yticks(np.arange(0, 1.1, 0.1))
#plt.yscale('log')
plt.ylim(0, 1)
plt.legend()
plt.show()
# Out:
# /var/folders/k_/3rw365c56w9f02q8nb4v2r4r0000gn/T/ipykernel_12172/769620210.py:10: RuntimeWarning: invalid value encountered in divide
#   proportions_nn = class_001_counts_nn / total_counts_nn

# %% [markdown]
# ## symbolnet model

# %%
from symbolnet import *

input_dim  = X_train.shape[1]
num_hidden = 1
output_dim = Y_train.shape[1]
model_dim = [input_dim, num_hidden, output_dim]

# operator choices per hidden symbolic layer
operators = [
    [['sin','tanh'], ['*']], # 1st symbolic layer [[unary], [binary]]
    #[['sin','tanh'], ['*']], # 2nd ...
            ]

# number of unary and binary operators per hidden symbolic layer
num_operators = [
    [30, 10], # 1st symbolic layer [num_unary, num_binary]
    #[12, 4], # 2nd ...
]

model = create_model(model_dim=model_dim,
                     operators=operators,
                     num_operators=num_operators)
model[0].summary()

nsr = neuralSR(model,
               # set target sparsity level per pruning type
               alpha_sparsity_input=0.1,
               alpha_sparsity_model=0.9,
               alpha_sparsity_unary=0.1,
               alpha_sparsity_binary=0.1)
nsr.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0003))


h = nsr.fit(X_train, Y_train, epochs=100, batch_size=128)
history = dict()
for key in h.history.keys():
    values = []
    values += h.history[key]
    history[key] = values

size_axis_title=10
size_axis_label=8
size_legend=7
plt.figure(figsize = (10,10))
axes = plt.subplot(2,2,1)
axes.set_ylim([-0.05,1.1])
plt.xticks(fontsize = size_axis_label) 
plt.yticks(fontsize = size_axis_label) 
axes.plot(history['accuracy'], label='Accuracy', linestyle='solid', c='r')
axes.plot(history['sparsity_model'], label='Sparsity (weight)', linestyle='solid', c='g')
#axes.plot(history['sparsity_input'], label='Sparsity (input)', linestyle='solid', c='b')
axes.plot(history['sparsity_unary'], label='Sparsity (unary)', linestyle='solid', c='orange')
axes.plot(history['sparsity_binary'], label='Sparsity (binary)', linestyle='solid', c='brown')
axes.set_xlabel('Epoch', size=size_axis_title, loc='right')
axes.set_ylabel('Metric', size=size_axis_title, loc='top')
axes.legend(loc = 'best', frameon = False, fontsize = size_legend)
plt.show()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 2)]               0
#
#  input_sparsity (Input_spar  (None, 2)                 4
#  sity)
#
#  symbolic__layer (Symbolic_  (None, 40)                380
#  Layer)
#
#  symbolic__layer_1 (Symboli  (None, 3)                 252
#  c_Layer)
#
# =================================================================
# Total params: 636 (2.48 KB)
# Trainable params: 591 (2.31 KB)
# Non-trainable params: 45 (180.00 Byte)
# _________________________________________________________________
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/100
# 1774/1774 [==============================] - 5s 1ms/step - loss: 2.4316 - regression_loss: 0.5644 - accuracy: 0.5682 - sparsity_input: 0.0000e+00 - sparsity_model: 0.5240 - sparsity_unary: 0.0000e+00 - sparsity_binary: 0.0000e+00
# Epoch 2/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 1.4415 - regression_loss: 0.5028 - accuracy: 0.6233 - sparsity_input: 0.0000e+00 - sparsity_model: 0.6787 - sparsity_unary: 0.0000e+00 - sparsity_binary: 0.0000e+00
# Epoch 3/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 1.0808 - regression_loss: 0.4995 - accuracy: 0.6221 - sparsity_input: 0.0000e+00 - sparsity_model: 0.7487 - sparsity_unary: 0.1470 - sparsity_binary: 0.0617
# Epoch 4/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.7006 - regression_loss: 0.4975 - accuracy: 0.6227 - sparsity_input: 0.0000e+00 - sparsity_model: 0.8121 - sparsity_unary: 0.2557 - sparsity_binary: 0.1000
# Epoch 5/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.6479 - regression_loss: 0.4948 - accuracy: 0.6238 - sparsity_input: 0.0000e+00 - sparsity_model: 0.8521 - sparsity_unary: 0.2146 - sparsity_binary: 0.1000
# Epoch 6/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.6090 - regression_loss: 0.4908 - accuracy: 0.6258 - sparsity_input: 0.0000e+00 - sparsity_model: 0.8663 - sparsity_unary: 0.1823 - sparsity_binary: 0.1000
# Epoch 7/100
# 1774/1774 [==============================] - 3s 1ms/step - loss: 0.5827 - regression_loss: 0.4906 - accuracy: 0.6255 - sparsity_input: 0.0000e+00 - sparsity_model: 0.8777 - sparsity_unary: 0.1779 - sparsity_binary: 0.1000
# Epoch 8/100
# 1774/1774 [==============================] - 3s 1ms/step - loss: 0.5393 - regression_loss: 0.4944 - accuracy: 0.6236 - sparsity_input: 0.0000e+00 - sparsity_model: 0.8999 - sparsity_unary: 0.1519 - sparsity_binary: 0.1000
# Epoch 9/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4975 - regression_loss: 0.4933 - accuracy: 0.6243 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9028 - sparsity_unary: 0.1404 - sparsity_binary: 0.1005
# Epoch 10/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4933 - regression_loss: 0.4899 - accuracy: 0.6291 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9054 - sparsity_unary: 0.1333 - sparsity_binary: 0.1016
# Epoch 11/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4889 - regression_loss: 0.4887 - accuracy: 0.6339 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9197 - sparsity_unary: 0.1348 - sparsity_binary: 0.1003
# Epoch 12/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4883 - regression_loss: 0.4885 - accuracy: 0.6355 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9233 - sparsity_unary: 0.1349 - sparsity_binary: 0.1000
# Epoch 13/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4892 - regression_loss: 0.4887 - accuracy: 0.6352 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9232 - sparsity_unary: 0.1353 - sparsity_binary: 0.1000
# Epoch 14/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4885 - regression_loss: 0.4887 - accuracy: 0.6354 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9232 - sparsity_unary: 0.1352 - sparsity_binary: 0.1000
# Epoch 15/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4870 - regression_loss: 0.4833 - accuracy: 0.6415 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9212 - sparsity_unary: 0.1340 - sparsity_binary: 0.1000
# Epoch 16/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4750 - regression_loss: 0.4741 - accuracy: 0.6556 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9195 - sparsity_unary: 0.1335 - sparsity_binary: 0.1000
# Epoch 17/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4775 - regression_loss: 0.4765 - accuracy: 0.6569 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9195 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 18/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4755 - regression_loss: 0.4768 - accuracy: 0.6574 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 19/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4766 - regression_loss: 0.4766 - accuracy: 0.6573 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1343 - sparsity_binary: 0.1000
# Epoch 20/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4802 - regression_loss: 0.4779 - accuracy: 0.6570 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9195 - sparsity_unary: 0.1346 - sparsity_binary: 0.1000
# Epoch 21/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4769 - regression_loss: 0.4772 - accuracy: 0.6574 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 22/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4758 - regression_loss: 0.4761 - accuracy: 0.6579 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 23/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4771 - regression_loss: 0.4768 - accuracy: 0.6577 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 24/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4768 - regression_loss: 0.4765 - accuracy: 0.6580 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 25/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4766 - regression_loss: 0.4765 - accuracy: 0.6582 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 26/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4768 - regression_loss: 0.4772 - accuracy: 0.6577 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 27/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4772 - regression_loss: 0.4769 - accuracy: 0.6574 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 28/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4761 - regression_loss: 0.4763 - accuracy: 0.6575 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1340 - sparsity_binary: 0.1000
# Epoch 29/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4755 - regression_loss: 0.4761 - accuracy: 0.6579 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 30/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4764 - regression_loss: 0.4766 - accuracy: 0.6576 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 31/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4771 - regression_loss: 0.4769 - accuracy: 0.6579 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 32/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4784 - regression_loss: 0.4765 - accuracy: 0.6583 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 33/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4762 - regression_loss: 0.4766 - accuracy: 0.6580 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 34/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4750 - regression_loss: 0.4761 - accuracy: 0.6581 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1340 - sparsity_binary: 0.1000
# Epoch 35/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4765 - regression_loss: 0.4764 - accuracy: 0.6580 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 36/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4784 - regression_loss: 0.4767 - accuracy: 0.6578 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1343 - sparsity_binary: 0.1000
# Epoch 37/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4757 - regression_loss: 0.4761 - accuracy: 0.6579 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 38/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4746 - regression_loss: 0.4759 - accuracy: 0.6578 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 39/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4750 - regression_loss: 0.4763 - accuracy: 0.6581 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 40/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4769 - regression_loss: 0.4758 - accuracy: 0.6581 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1340 - sparsity_binary: 0.1000
# Epoch 41/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4740 - regression_loss: 0.4762 - accuracy: 0.6580 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 42/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4763 - regression_loss: 0.4766 - accuracy: 0.6577 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 43/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4759 - regression_loss: 0.4763 - accuracy: 0.6579 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 44/100
# 1774/1774 [==============================] - 3s 2ms/step - loss: 0.4768 - regression_loss: 0.4763 - accuracy: 0.6578 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 45/100
# 1774/1774 [==============================] - 3s 2ms/step - loss: 0.4762 - regression_loss: 0.4760 - accuracy: 0.6579 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 46/100
# 1774/1774 [==============================] - 3s 1ms/step - loss: 0.4733 - regression_loss: 0.4763 - accuracy: 0.6579 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 47/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4759 - regression_loss: 0.4760 - accuracy: 0.6575 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 48/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4762 - regression_loss: 0.4765 - accuracy: 0.6578 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1343 - sparsity_binary: 0.1000
# Epoch 49/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4761 - regression_loss: 0.4761 - accuracy: 0.6580 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 50/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4766 - regression_loss: 0.4762 - accuracy: 0.6578 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 51/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4745 - regression_loss: 0.4763 - accuracy: 0.6579 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1343 - sparsity_binary: 0.1000
# Epoch 52/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4761 - regression_loss: 0.4759 - accuracy: 0.6580 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1340 - sparsity_binary: 0.1000
# Epoch 53/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4749 - regression_loss: 0.4765 - accuracy: 0.6580 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 54/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4758 - regression_loss: 0.4766 - accuracy: 0.6580 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 55/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4789 - regression_loss: 0.4762 - accuracy: 0.6579 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 56/100
# 1774/1774 [==============================] - 3s 1ms/step - loss: 0.4757 - regression_loss: 0.4762 - accuracy: 0.6576 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 57/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4765 - regression_loss: 0.4761 - accuracy: 0.6576 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 58/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4767 - regression_loss: 0.4760 - accuracy: 0.6580 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 59/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4757 - regression_loss: 0.4760 - accuracy: 0.6581 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 60/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4799 - regression_loss: 0.4765 - accuracy: 0.6577 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1340 - sparsity_binary: 0.1000
# Epoch 61/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4739 - regression_loss: 0.4763 - accuracy: 0.6580 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 62/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4753 - regression_loss: 0.4765 - accuracy: 0.6577 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1340 - sparsity_binary: 0.1000
# Epoch 63/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4768 - regression_loss: 0.4766 - accuracy: 0.6580 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 64/100
# 1774/1774 [==============================] - 3s 1ms/step - loss: 0.4771 - regression_loss: 0.4760 - accuracy: 0.6580 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1340 - sparsity_binary: 0.1000
# Epoch 65/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4750 - regression_loss: 0.4763 - accuracy: 0.6576 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 66/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4752 - regression_loss: 0.4764 - accuracy: 0.6581 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 67/100
# 1774/1774 [==============================] - 3s 1ms/step - loss: 0.4751 - regression_loss: 0.4762 - accuracy: 0.6580 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1343 - sparsity_binary: 0.1000
# Epoch 68/100
# 1774/1774 [==============================] - 3s 2ms/step - loss: 0.4746 - regression_loss: 0.4757 - accuracy: 0.6580 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1340 - sparsity_binary: 0.1000
# Epoch 69/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4757 - regression_loss: 0.4761 - accuracy: 0.6581 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 70/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4775 - regression_loss: 0.4761 - accuracy: 0.6580 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 71/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4777 - regression_loss: 0.4762 - accuracy: 0.6579 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 72/100
# 1774/1774 [==============================] - 3s 1ms/step - loss: 0.4762 - regression_loss: 0.4759 - accuracy: 0.6581 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 73/100
# 1774/1774 [==============================] - 3s 1ms/step - loss: 0.4755 - regression_loss: 0.4765 - accuracy: 0.6578 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 74/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4774 - regression_loss: 0.4761 - accuracy: 0.6578 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 75/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4766 - regression_loss: 0.4758 - accuracy: 0.6579 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 76/100
# 1774/1774 [==============================] - 3s 1ms/step - loss: 0.4758 - regression_loss: 0.4759 - accuracy: 0.6581 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 77/100
# 1774/1774 [==============================] - 3s 2ms/step - loss: 0.4749 - regression_loss: 0.4759 - accuracy: 0.6583 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 78/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4758 - regression_loss: 0.4762 - accuracy: 0.6578 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 79/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4766 - regression_loss: 0.4762 - accuracy: 0.6582 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 80/100
# 1774/1774 [==============================] - 3s 1ms/step - loss: 0.4771 - regression_loss: 0.4763 - accuracy: 0.6585 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1340 - sparsity_binary: 0.1000
# Epoch 81/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4775 - regression_loss: 0.4764 - accuracy: 0.6580 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1343 - sparsity_binary: 0.1000
# Epoch 82/100
# 1774/1774 [==============================] - 3s 2ms/step - loss: 0.4759 - regression_loss: 0.4760 - accuracy: 0.6582 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 83/100
# 1774/1774 [==============================] - 3s 1ms/step - loss: 0.4769 - regression_loss: 0.4764 - accuracy: 0.6582 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 84/100
# 1774/1774 [==============================] - 3s 1ms/step - loss: 0.4763 - regression_loss: 0.4763 - accuracy: 0.6580 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9195 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 85/100
# 1774/1774 [==============================] - 3s 1ms/step - loss: 0.4751 - regression_loss: 0.4758 - accuracy: 0.6580 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 86/100
# 1774/1774 [==============================] - 3s 1ms/step - loss: 0.4756 - regression_loss: 0.4766 - accuracy: 0.6583 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 87/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4761 - regression_loss: 0.4761 - accuracy: 0.6579 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 88/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4772 - regression_loss: 0.4758 - accuracy: 0.6583 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 89/100
# 1774/1774 [==============================] - 3s 1ms/step - loss: 0.4775 - regression_loss: 0.4762 - accuracy: 0.6581 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 90/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4754 - regression_loss: 0.4759 - accuracy: 0.6578 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 91/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4762 - regression_loss: 0.4762 - accuracy: 0.6577 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1340 - sparsity_binary: 0.1000
# Epoch 92/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4775 - regression_loss: 0.4768 - accuracy: 0.6583 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 93/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4782 - regression_loss: 0.4758 - accuracy: 0.6579 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 94/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4752 - regression_loss: 0.4758 - accuracy: 0.6580 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1343 - sparsity_binary: 0.1000
# Epoch 95/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4751 - regression_loss: 0.4757 - accuracy: 0.6577 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 96/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4738 - regression_loss: 0.4761 - accuracy: 0.6578 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 97/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4768 - regression_loss: 0.4762 - accuracy: 0.6580 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1341 - sparsity_binary: 0.1000
# Epoch 98/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4779 - regression_loss: 0.4762 - accuracy: 0.6580 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1342 - sparsity_binary: 0.1000
# Epoch 99/100
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4743 - regression_loss: 0.4761 - accuracy: 0.6581 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1340 - sparsity_binary: 0.1000
# Epoch 100/100
# 1774/1774 [==============================] - 3s 1ms/step - loss: 0.4766 - regression_loss: 0.4760 - accuracy: 0.6582 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9194 - sparsity_unary: 0.1340 - sparsity_binary: 0.1000

# %%
Y_sr_pred = nsr.model.predict(X_test)
print("Accuracy = {}".format(accuracy_score(np.argmax(Y_test, axis=1), np.argmax(Y_sr_pred, axis=1))))

def plot_roc(y_test, y_pred, labels):
    for x, label in enumerate(labels):        
        fpr, tpr, _ = roc_curve(y_test[:, x], y_pred[:, x])
        plt.plot(fpr, tpr, label='{0}, {1:.1f}'.format(label, auc(fpr, tpr)*100.), linestyle='-')
    #plt.semilogy()
    #plt.semilogx()
    plt.ylabel("Signal Efficiency")
    plt.xlabel("Background Efficiency")
    #plt.ylim(0.00001, 1)
    #plt.xlim(0.00001, 1)
    plt.grid(True)
    plt.legend(loc='best', fontsize=10)  
    
plt.figure(figsize=(4, 4))
plot_roc(Y_test, Y_sr_pred, ['Low pT (pos)','Low pT (neg)','High pT'])
#plot_roc(Y_test, Y_sr_pred, [' '])
# Out:
# 15625/15625 [==============================] - 8s 472us/step
# Accuracy = 0.48155

# %%
custom_bins = np.arange(-4.5, 4.5, 0.04)
bin_centers = 0.5 * (custom_bins[:-1] + custom_bins[1:])

indices_001_sr = np.argmax(Y_sr_pred, axis=1) == 2

total_counts_sr, _ = np.histogram(pt_truth_test, bins=custom_bins)
class_001_counts_sr, _ = np.histogram(pt_truth_test[indices_001_sr], bins=custom_bins)

proportions_sr = class_001_counts_sr / total_counts_sr
proportions_sr = np.nan_to_num(proportions_sr)

plt.scatter(bin_centers, proportions_nn, marker='.', label='nn', alpha=0.5, color='blue')
plt.scatter(bin_centers, proportions_sr, marker='.', label='sr', alpha=0.5, color='red')
plt.axvline(x=0.2, color='grey', linestyle='--', alpha=0.5)
plt.axvline(x=-0.2, color='grey', linestyle='--', alpha=0.5)

plt.legend(fontsize=10)
plt.xlabel('True pT [GeV]')
plt.ylabel('Fraction')
plt.title('Fraction of clusters selected as having |pT| > 0.2 GeV')
plt.yticks(np.arange(0, 1.1, 0.1))
#plt.yscale('log')
plt.ylim(0, 1)
plt.legend()
plt.show()


expressions_masked, complexity, sparsity_input, sparsity_model, sparsity_unary, sparsity_binary = get_expressions(nsr)
print('Unroll network into symbolic expressions (input sparsity = {0:.3f}; model sparsity = {1:.3f}; unary sparsity = {2:.3f}; binary sparsity = {2:.3f})\n--------------'.format(sparsity_input, sparsity_model, sparsity_unary, sparsity_binary))
print('Mean complexity = {0:.1f}\n--------------'.format(np.mean(complexity)))
for i in range(expressions_masked.shape[1]):
    print('expr_{0} (complexity = {1}):\n\n{2}\n-------------------------------------'.format(i,complexity[i],expressions_masked[i]))
# Out:
# /var/folders/k_/3rw365c56w9f02q8nb4v2r4r0000gn/T/ipykernel_12172/3141202776.py:9: RuntimeWarning: invalid value encountered in divide
#   proportions_sr = class_001_counts_sr / total_counts_sr
# Remaining Inputs after pruning: [[x0 x1]]
#
# Unroll network into symbolic expressions (input sparsity = 0.000; model sparsity = 0.919; unary sparsity = 0.133; binary sparsity = 0.133)
# --------------
# Mean complexity = 24.7
# --------------
# expr_0 (complexity = 13):
#
# 0.5*sin(1.1*x0 + 1.5*x1 - 0.4) + 0.48
# -------------------------------------
# expr_1 (complexity = 25):
#
# -0.21*x0 - 0.31*x1 + 0.57*(0.44*x0 + 0.56*x1)*(0.29*x0 + 0.38*x1 - 0.47) + 0.27
# -------------------------------------
# expr_2 (complexity = 36):
#
# 0.15*x0 + 0.22*x1 - 0.42*(0.44*x0 + 0.56*x1)*(0.29*x0 + 0.38*x1 - 0.47) - 0.38*sin(1.1*x0 + 1.5*x1 - 0.4) + 0.27
# -------------------------------------
