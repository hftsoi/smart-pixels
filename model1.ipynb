# %%
import h5py
import glob
import os
import sys
import sympy
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc, accuracy_score
from sklearn.preprocessing import StandardScaler
import tensorflow.keras.backend as K
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import roc_curve, auc, accuracy_score, r2_score
from tensorflow.keras.regularizers import Regularizer
from tensorflow.keras.initializers import Zeros, RandomNormal
from tensorflow.keras.layers import *
from tensorflow import keras
from tensorflow.keras import layers, models, Model
from sklearn.metrics import roc_curve, auc
import tensorflow.keras.backend as K
import qkeras
from qkeras import *

np.random.seed(42)
tf.random.set_seed(42)

X_train = np.load('X_train.npy', mmap_mode='r')
X_val = np.load('X_val.npy', mmap_mode='r')
X_test = np.load('X_test.npy', mmap_mode='r')
Y_train = np.load('Y_train.npy', mmap_mode='r')
Y_val = np.load('Y_val.npy', mmap_mode='r')
Y_test = np.load('Y_test.npy', mmap_mode='r')
pt_truth_test = np.load('pt_truth_test.npy', mmap_mode='r')

# model 1 (y-local, y-size)
X_train = X_train[:,:2]
X_val = X_val[:,:2]
X_test = X_test[:,:2]

# model 2 (y-local, [13 y rows of cluster charge])
#X_train = np.delete(X_train, [1], axis=1)
#X_val = np.delete(X_val, [1], axis=1)
#X_test = np.delete(X_test, [1], axis=1)

X_test = X_test[:500000]
Y_test = Y_test[:500000]
pt_truth_test = pt_truth_test[:500000]

print('X_train shape: ' + str(X_train.shape))
print('X_val   shape: ' + str(X_val.shape))
print('X_test  shape: ' + str(X_test.shape))
print('Y_train shape: ' + str(Y_train.shape))
print('Y_val   shape: ' + str(Y_val.shape))
print('Y_test  shape: ' + str(Y_test.shape))
print('pt_truth_test  shape: ' + str(pt_truth_test.shape))

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)
# Out:
# X_train shape: (226993, 2)
# X_val   shape: (18917, 2)
# X_test  shape: (500000, 2)
# Y_train shape: (226993, 3)
# Y_val   shape: (18917, 3)
# Y_test  shape: (500000, 3)
# pt_truth_test  shape: (500000,)

# %% [markdown]
# ## nn model

# %%
quantizer = quantized_bits(16, 6, alpha=1)
quantized_relu = 'quantized_relu(16, 6)'

x_input = keras.Input(shape=(X_train.shape[1],), name='input')

x = QDense(128, use_bias=True, name='dense1', kernel_quantizer=quantizer, bias_quantizer=quantizer)(x_input)
x = QActivation(quantized_relu, name='relu1')(x)
    
x = QDense(3, use_bias=True, name='dense2', kernel_quantizer=quantizer, bias_quantizer=quantizer)(x)
x = layers.Softmax(name='softmax')(x)
#x = layers.Activation('sigmoid')(x)

model = keras.Model(x_input, x, name='model')

model.compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=0.001),
              loss='categorical_crossentropy', metrics = ['accuracy'])
#model.compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=0.001),
#              loss='binary_crossentropy', metrics = ['accuracy'])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 2)]               0
#
#  dense1 (QDense)             (None, 128)               384
#
#  relu1 (QActivation)         (None, 128)               0
#
#  dense2 (QDense)             (None, 3)                 387
#
#  softmax (Softmax)           (None, 3)                 0
#
# =================================================================
# Total params: 771 (3.01 KB)
# Trainable params: 771 (3.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, Y_train,
                    validation_data = (X_val, Y_val),
                    epochs=80, batch_size=128)

plt.figure(figsize = (15,10))
axes = plt.subplot(2, 2, 1)
axes.plot(history.history['loss'], label = 'train loss')
axes.plot(history.history['val_loss'], label = 'val loss')
axes.legend(loc = "upper right")
axes.set_xlabel('Epoch')
axes.set_ylabel('Loss')


Y_nn_pred = model.predict(X_test)
print("Accuracy: {}".format(accuracy_score(np.argmax(Y_test, axis=1), np.argmax(Y_nn_pred, axis=1))))


def plot_roc(y_test, y_pred, labels):
    for x, label in enumerate(labels):        
        fpr, tpr, _ = roc_curve(y_test[:, x], y_pred[:, x])
        plt.plot(fpr, tpr, label='{0}, {1:.1f}'.format(label, auc(fpr, tpr)*100.), linestyle='-')
    #plt.semilogy()
    #plt.semilogx()
    plt.ylabel("Signal Efficiency")
    plt.xlabel("Background Efficiency")
    #plt.ylim(0.00001, 1)
    #plt.xlim(0.00001, 1)
    plt.grid(True)
    plt.legend(loc='best', fontsize=10)  
    
plt.figure(figsize=(4, 4))
plot_roc(Y_test, Y_nn_pred, ['Low pT (pos)','Low pT (neg)','High pT'])
#plot_roc(Y_test, Y_nn_pred, [' '])
# Out:
# Epoch 1/80
# 1774/1774 [==============================] - 1s 646us/step - loss: 0.7614 - accuracy: 0.6482 - val_loss: 0.7254 - val_accuracy: 0.6569
# Epoch 2/80
# 1774/1774 [==============================] - 1s 579us/step - loss: 0.7258 - accuracy: 0.6584 - val_loss: 0.7215 - val_accuracy: 0.6595
# Epoch 3/80
# 1774/1774 [==============================] - 1s 609us/step - loss: 0.7243 - accuracy: 0.6584 - val_loss: 0.7257 - val_accuracy: 0.6595
# Epoch 4/80
# 1774/1774 [==============================] - 1s 549us/step - loss: 0.7234 - accuracy: 0.6580 - val_loss: 0.7217 - val_accuracy: 0.6563
# Epoch 5/80
# 1774/1774 [==============================] - 1s 546us/step - loss: 0.7225 - accuracy: 0.6592 - val_loss: 0.7193 - val_accuracy: 0.6596
# Epoch 6/80
# 1774/1774 [==============================] - 1s 539us/step - loss: 0.7220 - accuracy: 0.6595 - val_loss: 0.7175 - val_accuracy: 0.6609
# Epoch 7/80
# 1774/1774 [==============================] - 1s 537us/step - loss: 0.7217 - accuracy: 0.6595 - val_loss: 0.7188 - val_accuracy: 0.6594
# Epoch 8/80
# 1774/1774 [==============================] - 1s 567us/step - loss: 0.7211 - accuracy: 0.6592 - val_loss: 0.7195 - val_accuracy: 0.6584
# Epoch 9/80
# 1774/1774 [==============================] - 1s 560us/step - loss: 0.7208 - accuracy: 0.6591 - val_loss: 0.7173 - val_accuracy: 0.6610
# Epoch 10/80
# 1774/1774 [==============================] - 1s 569us/step - loss: 0.7208 - accuracy: 0.6590 - val_loss: 0.7181 - val_accuracy: 0.6598
# Epoch 11/80
# 1774/1774 [==============================] - 1s 541us/step - loss: 0.7202 - accuracy: 0.6590 - val_loss: 0.7145 - val_accuracy: 0.6608
# Epoch 12/80
# 1774/1774 [==============================] - 1s 548us/step - loss: 0.7195 - accuracy: 0.6593 - val_loss: 0.7157 - val_accuracy: 0.6612
# Epoch 13/80
# 1774/1774 [==============================] - 1s 572us/step - loss: 0.7188 - accuracy: 0.6597 - val_loss: 0.7147 - val_accuracy: 0.6609
# 1774/1774 [==============================] - 1s 555us/step - loss: 0.7160 - accuracy: 0.6605 - val_loss: 0.7124 - val_accuracy: 0.6607
# Epoch 71/80
# 1774/1774 [==============================] - 1s 536us/step - loss: 0.7160 - accuracy: 0.6608 - val_loss: 0.7130 - val_accuracy: 0.6617
# Epoch 72/80
# 1774/1774 [==============================] - 1s 538us/step - loss: 0.7159 - accuracy: 0.6609 - val_loss: 0.7121 - val_accuracy: 0.6599
# Epoch 73/80
# 1774/1774 [==============================] - 1s 561us/step - loss: 0.7160 - accuracy: 0.6606 - val_loss: 0.7122 - val_accuracy: 0.6613
# Epoch 74/80
# 1774/1774 [==============================] - 1s 565us/step - loss: 0.7161 - accuracy: 0.6608 - val_loss: 0.7122 - val_accuracy: 0.6605
# Epoch 75/80
# 1774/1774 [==============================] - 1s 569us/step - loss: 0.7159 - accuracy: 0.6605 - val_loss: 0.7124 - val_accuracy: 0.6609
# Epoch 76/80
# 1774/1774 [==============================] - 1s 559us/step - loss: 0.7159 - accuracy: 0.6611 - val_loss: 0.7120 - val_accuracy: 0.6622
# Epoch 77/80
# 1774/1774 [==============================] - 1s 553us/step - loss: 0.7159 - accuracy: 0.6609 - val_loss: 0.7124 - val_accuracy: 0.6619
# Epoch 78/80
# 1774/1774 [==============================] - 1s 552us/step - loss: 0.7158 - accuracy: 0.6610 - val_loss: 0.7121 - val_accuracy: 0.6585
# Epoch 79/80
# 1774/1774 [==============================] - 1s 539us/step - loss: 0.7159 - accuracy: 0.6606 - val_loss: 0.7116 - val_accuracy: 0.6611
# Epoch 80/80
# 1774/1774 [==============================] - 1s 548us/step - loss: 0.7159 - accuracy: 0.6603 - val_loss: 0.7135 - val_accuracy: 0.6594
# 15625/15625 [==============================] - 4s 247us/step
# Accuracy: 0.501792

# %%
plt.figure(figsize=(4, 4))
custom_bins = np.arange(-4.5, 4.5, 0.04)
bin_centers = 0.5 * (custom_bins[:-1] + custom_bins[1:])

indices_001_nn = np.argmax(Y_nn_pred, axis=1) == 2

total_counts_nn, _ = np.histogram(pt_truth_test, bins=custom_bins)
class_001_counts_nn, _ = np.histogram(pt_truth_test[indices_001_nn], bins=custom_bins)

proportions_nn = class_001_counts_nn / total_counts_nn
proportions_nn = np.nan_to_num(proportions_nn)

plt.scatter(bin_centers, proportions_nn, marker='.', label='nn', alpha=0.5, color='blue')
plt.axvline(x=0.2, color='grey', linestyle='--', alpha=0.5)
plt.axvline(x=-0.2, color='grey', linestyle='--', alpha=0.5)

plt.legend(fontsize=10)
plt.xlabel('True pT [GeV]')
plt.ylabel('Fraction')
plt.title('Fraction of clusters selected as having |pT| > 0.2 GeV')
plt.yticks(np.arange(0, 1.1, 0.1))
#plt.yscale('log')
plt.ylim(0, 1)
plt.legend()
plt.show()
# Out:
# /var/folders/k_/3rw365c56w9f02q8nb4v2r4r0000gn/T/ipykernel_11512/769620210.py:10: RuntimeWarning: invalid value encountered in divide
#   proportions_nn = class_001_counts_nn / total_counts_nn

# %% [markdown]
# ## symbolnet model

# %%
from symbolnet import *

input_dim  = X_train.shape[1]
num_hidden = 1
output_dim = Y_train.shape[1]
model_dim = [input_dim, num_hidden, output_dim]

# operator choices per hidden symbolic layer
operators = [
    [['sin','tanh'], ['*']], # 1st symbolic layer [[unary], [binary]]
    #[['sin','tanh'], ['*']], # 2nd ...
            ]

# number of unary and binary operators per hidden symbolic layer
num_operators = [
    [60, 20], # 1st symbolic layer [num_unary, num_binary]
    #[12, 4], # 2nd ...
]

model = create_model(model_dim=model_dim,
                     operators=operators,
                     num_operators=num_operators)
model[0].summary()

nsr = neuralSR(model,
               # set target sparsity level per pruning type
               alpha_sparsity_input=0.1,
               alpha_sparsity_model=0.9,
               alpha_sparsity_unary=0.1,
               alpha_sparsity_binary=0.1)
nsr.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0003))


h = nsr.fit(X_train, Y_train, epochs=100, batch_size=128)
history = dict()
for key in h.history.keys():
    values = []
    values += h.history[key]
    history[key] = values

size_axis_title=10
size_axis_label=8
size_legend=7
plt.figure(figsize = (10,10))
axes = plt.subplot(2,2,1)
axes.set_ylim([-0.05,1.1])
plt.xticks(fontsize = size_axis_label) 
plt.yticks(fontsize = size_axis_label) 
axes.plot(history['accuracy'], label='Accuracy', linestyle='solid', c='r')
axes.plot(history['sparsity_model'], label='Sparsity (weight)', linestyle='solid', c='g')
#axes.plot(history['sparsity_input'], label='Sparsity (input)', linestyle='solid', c='b')
axes.plot(history['sparsity_unary'], label='Sparsity (unary)', linestyle='solid', c='orange')
axes.plot(history['sparsity_binary'], label='Sparsity (binary)', linestyle='solid', c='brown')
axes.set_xlabel('Epoch', size=size_axis_title, loc='right')
axes.set_ylabel('Metric', size=size_axis_title, loc='top')
axes.legend(loc = 'best', frameon = False, fontsize = size_legend)
plt.show()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 2)]               0
#
#  input_sparsity (Input_spar  (None, 2)                 4
#  sity)
#
#  symbolic__layer (Symbolic_  (None, 80)                760
#  Layer)
#
#  symbolic__layer_1 (Symboli  (None, 3)                 492
#  c_Layer)
#
# =================================================================
# Total params: 1256 (4.91 KB)
# Trainable params: 1171 (4.57 KB)
# Non-trainable params: 85 (340.00 Byte)
# _________________________________________________________________
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/100
# 1774/1774 [==============================] - 9s 3ms/step - loss: 2.3852 - regression_loss: 0.5561 - accuracy: 0.5917 - sparsity_input: 0.0000e+00 - sparsity_model: 0.5484 - sparsity_unary: 0.0000e+00 - sparsity_binary: 0.0000e+00
# Epoch 2/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 1.4394 - regression_loss: 0.5031 - accuracy: 0.6135 - sparsity_input: 0.0000e+00 - sparsity_model: 0.6997 - sparsity_unary: 0.0000e+00 - sparsity_binary: 0.0000e+00
# Epoch 3/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 1.0826 - regression_loss: 0.5021 - accuracy: 0.6146 - sparsity_input: 0.0000e+00 - sparsity_model: 0.7677 - sparsity_unary: 0.2566 - sparsity_binary: 0.2471
# Epoch 4/100
# 1774/1774 [==============================] - 6s 3ms/step - loss: 0.7038 - regression_loss: 0.5012 - accuracy: 0.6160 - sparsity_input: 0.0000e+00 - sparsity_model: 0.8279 - sparsity_unary: 0.4464 - sparsity_binary: 0.4000
# Epoch 5/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.6473 - regression_loss: 0.4998 - accuracy: 0.6166 - sparsity_input: 0.0000e+00 - sparsity_model: 0.8697 - sparsity_unary: 0.4287 - sparsity_binary: 0.4000
# Epoch 6/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.6026 - regression_loss: 0.4978 - accuracy: 0.6175 - sparsity_input: 0.0000e+00 - sparsity_model: 0.8917 - sparsity_unary: 0.4148 - sparsity_binary: 0.4000
# Epoch 7/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.5014 - regression_loss: 0.4946 - accuracy: 0.6188 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9030 - sparsity_unary: 0.4146 - sparsity_binary: 0.4000
# Epoch 8/100
# 1774/1774 [==============================] - 6s 3ms/step - loss: 0.4932 - regression_loss: 0.4926 - accuracy: 0.6211 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9073 - sparsity_unary: 0.4135 - sparsity_binary: 0.4000
# Epoch 9/100
# 1774/1774 [==============================] - 6s 4ms/step - loss: 0.4907 - regression_loss: 0.4899 - accuracy: 0.6231 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9121 - sparsity_unary: 0.4232 - sparsity_binary: 0.4000
# Epoch 10/100
# 1774/1774 [==============================] - 6s 4ms/step - loss: 0.4874 - regression_loss: 0.4878 - accuracy: 0.6230 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9141 - sparsity_unary: 0.4141 - sparsity_binary: 0.4000
# Epoch 11/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4871 - regression_loss: 0.4864 - accuracy: 0.6242 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9174 - sparsity_unary: 0.4090 - sparsity_binary: 0.4000
# Epoch 12/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4848 - regression_loss: 0.4848 - accuracy: 0.6252 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9169 - sparsity_unary: 0.4093 - sparsity_binary: 0.4000
# Epoch 13/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4858 - regression_loss: 0.4858 - accuracy: 0.6258 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9170 - sparsity_unary: 0.4088 - sparsity_binary: 0.4068
# Epoch 14/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4908 - regression_loss: 0.4922 - accuracy: 0.6240 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9175 - sparsity_unary: 0.4093 - sparsity_binary: 0.4122
# Epoch 15/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4961 - regression_loss: 0.4959 - accuracy: 0.6137 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9180 - sparsity_unary: 0.4127 - sparsity_binary: 0.4375
# Epoch 16/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4971 - regression_loss: 0.4982 - accuracy: 0.6155 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9180 - sparsity_unary: 0.4077 - sparsity_binary: 0.4297
# Epoch 17/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4969 - regression_loss: 0.4945 - accuracy: 0.6191 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9220 - sparsity_unary: 0.4017 - sparsity_binary: 0.4200
# Epoch 18/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4936 - regression_loss: 0.4926 - accuracy: 0.6186 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9237 - sparsity_unary: 0.4004 - sparsity_binary: 0.4004
# Epoch 19/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4904 - regression_loss: 0.4889 - accuracy: 0.6176 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9288 - sparsity_unary: 0.4062 - sparsity_binary: 0.4000
# Epoch 20/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4890 - regression_loss: 0.4867 - accuracy: 0.6262 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9289 - sparsity_unary: 0.3979 - sparsity_binary: 0.4000
# Epoch 21/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4805 - regression_loss: 0.4780 - accuracy: 0.6372 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9287 - sparsity_unary: 0.3853 - sparsity_binary: 0.4000
# Epoch 22/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4739 - regression_loss: 0.4719 - accuracy: 0.6452 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9294 - sparsity_unary: 0.3834 - sparsity_binary: 0.4004
# Epoch 23/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4689 - regression_loss: 0.4672 - accuracy: 0.6521 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9300 - sparsity_unary: 0.3932 - sparsity_binary: 0.4018
# Epoch 24/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4621 - regression_loss: 0.4612 - accuracy: 0.6567 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9315 - sparsity_unary: 0.3998 - sparsity_binary: 0.4016
# Epoch 25/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4567 - regression_loss: 0.4561 - accuracy: 0.6591 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9353 - sparsity_unary: 0.3955 - sparsity_binary: 0.4010
# Epoch 26/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4541 - regression_loss: 0.4540 - accuracy: 0.6602 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9347 - sparsity_unary: 0.3909 - sparsity_binary: 0.4001
# Epoch 27/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4535 - regression_loss: 0.4536 - accuracy: 0.6598 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9322 - sparsity_unary: 0.3923 - sparsity_binary: 0.4010
# Epoch 28/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4544 - regression_loss: 0.4553 - accuracy: 0.6597 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9338 - sparsity_unary: 0.3882 - sparsity_binary: 0.4007
# Epoch 29/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4588 - regression_loss: 0.4590 - accuracy: 0.6587 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9335 - sparsity_unary: 0.3909 - sparsity_binary: 0.4007
# Epoch 30/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4582 - regression_loss: 0.4587 - accuracy: 0.6582 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9334 - sparsity_unary: 0.3946 - sparsity_binary: 0.4042
# Epoch 31/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4551 - regression_loss: 0.4564 - accuracy: 0.6589 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9327 - sparsity_unary: 0.3968 - sparsity_binary: 0.4058
# Epoch 32/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4570 - regression_loss: 0.4566 - accuracy: 0.6596 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9317 - sparsity_unary: 0.3956 - sparsity_binary: 0.4027
# Epoch 33/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4574 - regression_loss: 0.4562 - accuracy: 0.6597 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9313 - sparsity_unary: 0.3962 - sparsity_binary: 0.4034
# Epoch 34/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4555 - regression_loss: 0.4564 - accuracy: 0.6592 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9342 - sparsity_unary: 0.3996 - sparsity_binary: 0.4013
# Epoch 35/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4549 - regression_loss: 0.4549 - accuracy: 0.6597 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9351 - sparsity_unary: 0.3977 - sparsity_binary: 0.4002
# Epoch 36/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4544 - regression_loss: 0.4541 - accuracy: 0.6597 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9350 - sparsity_unary: 0.3981 - sparsity_binary: 0.4007
# Epoch 37/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4540 - regression_loss: 0.4542 - accuracy: 0.6602 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9354 - sparsity_unary: 0.3983 - sparsity_binary: 0.4002
# Epoch 38/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4534 - regression_loss: 0.4532 - accuracy: 0.6601 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9348 - sparsity_unary: 0.3979 - sparsity_binary: 0.4008
# Epoch 39/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4537 - regression_loss: 0.4534 - accuracy: 0.6606 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9333 - sparsity_unary: 0.3974 - sparsity_binary: 0.4008
# Epoch 40/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4539 - regression_loss: 0.4535 - accuracy: 0.6608 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9329 - sparsity_unary: 0.3971 - sparsity_binary: 0.4008
# Epoch 41/100
# 1774/1774 [==============================] - 6s 3ms/step - loss: 0.4518 - regression_loss: 0.4542 - accuracy: 0.6593 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9325 - sparsity_unary: 0.3941 - sparsity_binary: 0.4006
# Epoch 42/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4549 - regression_loss: 0.4548 - accuracy: 0.6598 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9320 - sparsity_unary: 0.3932 - sparsity_binary: 0.4014
# Epoch 43/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4549 - regression_loss: 0.4542 - accuracy: 0.6597 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9335 - sparsity_unary: 0.3949 - sparsity_binary: 0.4012
# Epoch 44/100
# 1774/1774 [==============================] - 6s 3ms/step - loss: 0.4537 - regression_loss: 0.4525 - accuracy: 0.6602 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9340 - sparsity_unary: 0.3943 - sparsity_binary: 0.4006
# Epoch 45/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4528 - regression_loss: 0.4524 - accuracy: 0.6605 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9342 - sparsity_unary: 0.3928 - sparsity_binary: 0.4025
# Epoch 46/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4494 - regression_loss: 0.4518 - accuracy: 0.6599 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9344 - sparsity_unary: 0.3920 - sparsity_binary: 0.4031
# Epoch 47/100
# 1774/1774 [==============================] - 7s 4ms/step - loss: 0.4508 - regression_loss: 0.4519 - accuracy: 0.6601 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9344 - sparsity_unary: 0.3904 - sparsity_binary: 0.4026
# Epoch 48/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4509 - regression_loss: 0.4512 - accuracy: 0.6602 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9345 - sparsity_unary: 0.3912 - sparsity_binary: 0.4023
# Epoch 49/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4512 - regression_loss: 0.4513 - accuracy: 0.6601 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9354 - sparsity_unary: 0.3912 - sparsity_binary: 0.4025
# Epoch 50/100
# 1774/1774 [==============================] - 6s 3ms/step - loss: 0.4517 - regression_loss: 0.4511 - accuracy: 0.6599 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9358 - sparsity_unary: 0.3909 - sparsity_binary: 0.4023
# Epoch 51/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4504 - regression_loss: 0.4511 - accuracy: 0.6600 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9378 - sparsity_unary: 0.3903 - sparsity_binary: 0.4023
# Epoch 52/100
# 1774/1774 [==============================] - 6s 3ms/step - loss: 0.4506 - regression_loss: 0.4508 - accuracy: 0.6601 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9376 - sparsity_unary: 0.3891 - sparsity_binary: 0.4010
# Epoch 53/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4496 - regression_loss: 0.4509 - accuracy: 0.6602 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9379 - sparsity_unary: 0.3888 - sparsity_binary: 0.4016
# Epoch 54/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4508 - regression_loss: 0.4507 - accuracy: 0.6601 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9377 - sparsity_unary: 0.3889 - sparsity_binary: 0.4009
# Epoch 55/100
# 1774/1774 [==============================] - 6s 3ms/step - loss: 0.4516 - regression_loss: 0.4507 - accuracy: 0.6599 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9380 - sparsity_unary: 0.3886 - sparsity_binary: 0.4006
# Epoch 56/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4508 - regression_loss: 0.4508 - accuracy: 0.6605 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9380 - sparsity_unary: 0.3883 - sparsity_binary: 0.4007
# Epoch 57/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4507 - regression_loss: 0.4499 - accuracy: 0.6597 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9369 - sparsity_unary: 0.3887 - sparsity_binary: 0.4007
# Epoch 58/100
# 1774/1774 [==============================] - 6s 3ms/step - loss: 0.4493 - regression_loss: 0.4489 - accuracy: 0.6598 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9364 - sparsity_unary: 0.3864 - sparsity_binary: 0.4005
# Epoch 59/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4475 - regression_loss: 0.4485 - accuracy: 0.6598 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9358 - sparsity_unary: 0.3866 - sparsity_binary: 0.4003
# Epoch 60/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4504 - regression_loss: 0.4478 - accuracy: 0.6601 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9358 - sparsity_unary: 0.3861 - sparsity_binary: 0.4004
# Epoch 61/100
# 1774/1774 [==============================] - 6s 3ms/step - loss: 0.4458 - regression_loss: 0.4478 - accuracy: 0.6599 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9373 - sparsity_unary: 0.3856 - sparsity_binary: 0.4003
# Epoch 62/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4465 - regression_loss: 0.4473 - accuracy: 0.6599 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9382 - sparsity_unary: 0.3857 - sparsity_binary: 0.4000
# Epoch 63/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4466 - regression_loss: 0.4471 - accuracy: 0.6600 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9390 - sparsity_unary: 0.3851 - sparsity_binary: 0.4000
# Epoch 64/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4481 - regression_loss: 0.4471 - accuracy: 0.6601 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9392 - sparsity_unary: 0.3847 - sparsity_binary: 0.4000
# Epoch 65/100
# 1774/1774 [==============================] - 6s 3ms/step - loss: 0.4455 - regression_loss: 0.4470 - accuracy: 0.6601 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9392 - sparsity_unary: 0.3834 - sparsity_binary: 0.4000
# Epoch 66/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4463 - regression_loss: 0.4468 - accuracy: 0.6600 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9393 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 67/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4468 - regression_loss: 0.4466 - accuracy: 0.6599 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9392 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 68/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4460 - regression_loss: 0.4465 - accuracy: 0.6598 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9391 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 69/100
# 1774/1774 [==============================] - 6s 3ms/step - loss: 0.4459 - regression_loss: 0.4465 - accuracy: 0.6601 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9390 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 70/100
# 1774/1774 [==============================] - 6s 3ms/step - loss: 0.4470 - regression_loss: 0.4465 - accuracy: 0.6599 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9385 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 71/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4470 - regression_loss: 0.4468 - accuracy: 0.6598 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9378 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 72/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4467 - regression_loss: 0.4468 - accuracy: 0.6597 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9390 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 73/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4459 - regression_loss: 0.4464 - accuracy: 0.6599 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9371 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 74/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4470 - regression_loss: 0.4465 - accuracy: 0.6598 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9373 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 75/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4467 - regression_loss: 0.4464 - accuracy: 0.6600 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9384 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 76/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4465 - regression_loss: 0.4463 - accuracy: 0.6598 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9380 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 77/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4461 - regression_loss: 0.4463 - accuracy: 0.6601 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9374 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 78/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4472 - regression_loss: 0.4497 - accuracy: 0.6599 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9375 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 79/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4505 - regression_loss: 0.4504 - accuracy: 0.6599 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9374 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 80/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4511 - regression_loss: 0.4500 - accuracy: 0.6598 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9373 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 81/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4508 - regression_loss: 0.4496 - accuracy: 0.6600 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9373 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 82/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4495 - regression_loss: 0.4494 - accuracy: 0.6598 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9373 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 83/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4505 - regression_loss: 0.4490 - accuracy: 0.6597 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9373 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 84/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4484 - regression_loss: 0.4487 - accuracy: 0.6597 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9373 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 85/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4605 - regression_loss: 0.4673 - accuracy: 0.6563 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9380 - sparsity_unary: 0.3836 - sparsity_binary: 0.4000
# Epoch 86/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4693 - regression_loss: 0.4654 - accuracy: 0.6550 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9396 - sparsity_unary: 0.3836 - sparsity_binary: 0.4000
# Epoch 87/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4549 - regression_loss: 0.4541 - accuracy: 0.6582 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9381 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 88/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4532 - regression_loss: 0.4519 - accuracy: 0.6589 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9369 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 89/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4525 - regression_loss: 0.4498 - accuracy: 0.6593 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9356 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 90/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4488 - regression_loss: 0.4484 - accuracy: 0.6595 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9347 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 91/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4477 - regression_loss: 0.4474 - accuracy: 0.6597 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9336 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 92/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4475 - regression_loss: 0.4466 - accuracy: 0.6601 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9335 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 93/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4488 - regression_loss: 0.4462 - accuracy: 0.6597 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9325 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 94/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4477 - regression_loss: 0.4490 - accuracy: 0.6595 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9318 - sparsity_unary: 0.3834 - sparsity_binary: 0.4000
# Epoch 95/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4554 - regression_loss: 0.4553 - accuracy: 0.6581 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9318 - sparsity_unary: 0.3835 - sparsity_binary: 0.4000
# Epoch 96/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4462 - regression_loss: 0.4464 - accuracy: 0.6599 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9318 - sparsity_unary: 0.3834 - sparsity_binary: 0.4000
# Epoch 97/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4462 - regression_loss: 0.4455 - accuracy: 0.6598 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9318 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 98/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4474 - regression_loss: 0.4453 - accuracy: 0.6601 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9318 - sparsity_unary: 0.3833 - sparsity_binary: 0.4000
# Epoch 99/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4474 - regression_loss: 0.4516 - accuracy: 0.6588 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9317 - sparsity_unary: 0.3835 - sparsity_binary: 0.4000
# Epoch 100/100
# 1774/1774 [==============================] - 5s 3ms/step - loss: 0.4554 - regression_loss: 0.4542 - accuracy: 0.6583 - sparsity_input: 0.0000e+00 - sparsity_model: 0.9319 - sparsity_unary: 0.3835 - sparsity_binary: 0.4000

# %%
Y_sr_pred = nsr.model.predict(X_test)
print("Accuracy = {}".format(accuracy_score(np.argmax(Y_test, axis=1), np.argmax(Y_sr_pred, axis=1))))

def plot_roc(y_test, y_pred, labels):
    for x, label in enumerate(labels):        
        fpr, tpr, _ = roc_curve(y_test[:, x], y_pred[:, x])
        plt.plot(fpr, tpr, label='{0}, {1:.1f}'.format(label, auc(fpr, tpr)*100.), linestyle='-')
    #plt.semilogy()
    #plt.semilogx()
    plt.ylabel("Signal Efficiency")
    plt.xlabel("Background Efficiency")
    #plt.ylim(0.00001, 1)
    #plt.xlim(0.00001, 1)
    plt.grid(True)
    plt.legend(loc='best', fontsize=10)  
    
plt.figure(figsize=(4, 4))
plot_roc(Y_test, Y_sr_pred, ['Low pT (pos)','Low pT (neg)','High pT'])
#plot_roc(Y_test, Y_sr_pred, [' '])
# Out:
# 15625/15625 [==============================] - 10s 601us/step
# Accuracy = 0.50055

# %%
custom_bins = np.arange(-4.5, 4.5, 0.04)
bin_centers = 0.5 * (custom_bins[:-1] + custom_bins[1:])

indices_001_sr = np.argmax(Y_sr_pred, axis=1) == 2

total_counts_sr, _ = np.histogram(pt_truth_test, bins=custom_bins)
class_001_counts_sr, _ = np.histogram(pt_truth_test[indices_001_sr], bins=custom_bins)

proportions_sr = class_001_counts_sr / total_counts_sr
proportions_sr = np.nan_to_num(proportions_sr)

plt.scatter(bin_centers, proportions_nn, marker='.', label='nn', alpha=0.5, color='blue')
plt.scatter(bin_centers, proportions_sr, marker='.', label='sr', alpha=0.5, color='red')
plt.axvline(x=0.2, color='grey', linestyle='--', alpha=0.5)
plt.axvline(x=-0.2, color='grey', linestyle='--', alpha=0.5)

plt.legend(fontsize=10)
plt.xlabel('True pT [GeV]')
plt.ylabel('Fraction')
plt.title('Fraction of clusters selected as having |pT| > 0.2 GeV')
plt.yticks(np.arange(0, 1.1, 0.1))
#plt.yscale('log')
plt.ylim(0, 1)
plt.legend()
plt.show()


expressions_masked, complexity, sparsity_input, sparsity_model, sparsity_unary, sparsity_binary = get_expressions(nsr)
print('Unroll network into symbolic expressions (input sparsity = {0:.3f}; model sparsity = {1:.3f}; unary sparsity = {2:.3f}; binary sparsity = {2:.3f})\n--------------'.format(sparsity_input, sparsity_model, sparsity_unary, sparsity_binary))
print('Mean complexity = {0:.1f}\n--------------'.format(np.mean(complexity)))
for i in range(expressions_masked.shape[1]):
    print('expr_{0} (complexity = {1}):\n\n{2}\n-------------------------------------'.format(i,complexity[i],expressions_masked[i]))
# Out:
# /var/folders/k_/3rw365c56w9f02q8nb4v2r4r0000gn/T/ipykernel_11512/3141202776.py:9: RuntimeWarning: invalid value encountered in divide
#   proportions_sr = class_001_counts_sr / total_counts_sr
# Remaining Inputs after pruning: [[x0 x1]]
#
# Unroll network into symbolic expressions (input sparsity = 0.000; model sparsity = 0.932; unary sparsity = 0.383; binary sparsity = 0.383)
# --------------
# Mean complexity = 53.7
# --------------
# expr_0 (complexity = 66):
#
# -0.085*x0 - 0.085*x1 + 0.31*(-0.36*x0 - 0.048*x1)*(0.35*x0 + 0.041*x1) + 0.14*sin(1.4*x0 + 1.6*x1) - 0.15*tanh(0.25*x0 + 0.35*x1) + 0.58*tanh(1.3*x0 + 1.7*x1 - 0.022) - 0.13*tanh(1.8*x0 + 2.3*x1 + 1.1) + 0.46
# -------------------------------------
# expr_1 (complexity = 46):
#
# 0.12*x0 + 0.12*x1 - 0.21*(-0.36*x0 - 0.048*x1)*(0.35*x0 + 0.041*x1) - 0.2*tanh(1.3*x0 + 1.7*x1 - 0.022) - 0.39*tanh(1.8*x0 + 2.3*x1 + 1.1) + 0.48
# -------------------------------------
# expr_2 (complexity = 49):
#
# -0.13*(-0.36*x0 - 0.048*x1)*(0.35*x0 + 0.041*x1) - 0.35*sin(1.4*x0 + 1.6*x1) - 0.59*tanh(0.25*x0 + 0.35*x1) + 0.55*tanh(1.8*x0 + 2.3*x1 + 1.1) + 0.045
# -------------------------------------
